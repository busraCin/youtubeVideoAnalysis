# %%
import pandas as pd

# %%
youtubeDataSet = pd.read_csv("USvideos.csv")
youtubeDataSet
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 23357  pH7VfJDq7f4      18.12.03
# 23358  hV-yHbbrKRA      18.12.03
# 23359  CwKp6Xhy3_4      18.12.03
# 23360  vQiiNGllGQo      18.12.03
# 23361  2afSbqlp5HU      18.12.03
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# ...

# %%
youtubeDataSet.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
youtubeDataSet.drop(["video_id","trending_date","publish_time","thumbnail_link",
"comments_disabled","ratings_disabled","video_error_or_removed"],
                    axis=1,inplace = True)

# %%
youtubeDataSet
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
len(youtubeDataSet.columns)
# Out:
# 9

# %%
len(youtubeDataSet.index)
# Out:
# 23362

# %%
youtubeDataSet["likes"].mean()
# Out:
# 45085.35972947522

# %%
youtubeDataSet["dislikes"].mean()
# Out:
# 2809.7094426847016

# %%
youtubeDataSet[youtubeDataSet["views"] == youtubeDataSet["views"].max()]
# Out:
#                                                   title      channel_title  \
# 6181  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
#
#       category_id                                               tags  \
# 6181           24  Rewind|"Rewind 2017"|"youtube rewind 2017"|"#Y...
#
#           views    likes  dislikes  comment_count  \
# 6181  149376127  3093544   1643059         810698
#
#                                             description
# 6181  YouTube Rewind 2017. Celebrating the videos, p...

# %%
youtubeDataSet[youtubeDataSet["views"] == youtubeDataSet["views"].max()]["title"].iloc[0]
# Out:
# 'YouTube Rewind: The Shape of 2017 | #YouTubeRewind'

# %%
youtubeDataSet[youtubeDataSet["views"] == youtubeDataSet["views"].min()]["title"].iloc[0]
# Out:
# '1 dead, others injured after Ky. school shooting'

# %%
youtubeDataSet.groupby("category_id").mean()[["comment_count"]]
# Out:
#              comment_count
# category_id
# 1              6003.651813
# 2              1730.438235
# 10            10383.559418
# 15             2474.376054
# 17             3256.199515
# 19             1833.011450
# 20             7578.383607
# 22             4491.865854
# 23             5432.868554
# 24             7178.388176
# 25             1523.749869
# 26             4992.165997
# 27             2143.574850
# 28             3350.945159
# 29           100071.562500
# 43             1340.375000

# %%
youtubeDataSet["category_id"].value_counts()
# Out:
# 24    5379
# 10    3366
# 26    2241
# 23    1978
# 25    1907
# 22    1886
# 28    1477
# 1     1324
# 17    1238
# 27    1002
# 15     593
# 2      340
# 20     305
# 19     262
# 29      48
# 43      16
# Name: category_id, dtype: int64

# %%
youtubeDataSet["title_lenght"] = youtubeDataSet["title"].apply(len)

# %%
youtubeDataSet
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
def countTag(tag):
    tagList = tag.split("|")
    return len(tagList)
youtubeDataSet["tag_count"]=youtubeDataSet["tags"].apply(countTag)
youtubeDataSet
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
list(youtubeDataSet["likes"].iteritems())
# Out:
# [(0, 57527),
#  (1, 97185),
#  (2, 146033),
#  (3, 10172),
#  (4, 132235),
#  (5, 9763),
#  (6, 15993),
#  (7, 23663),
#  (8, 3543),
#  (9, 12654),
#  (10, 655),
#  (11, 1576),
#  (12, 114188),
#  (13, 7848),
#  (14, 7473),
#  (15, 9419),
#  (16, 8011),
#  (17, 5398),
#  (18, 11963),
#  (19, 8421),
#  (20, 9586),
#  (21, 3585),
#  (22, 11758),
#  (23, 1707),
#  (24, 4884),
#  (25, 8676),
#  (26, 4687),
#  (27, 9033),
#  (28, 156),
#  (29, 715),
#  (30, 4035),
#  (31, 119),
#  (32, 787419),
#  (33, 3781),
#  (34, 1661),
#  (35, 2486),
#  (36, 7515),
#  (37, 1318),
#  (38, 38397),
#  (39, 6927),
#  (40, 5389),
#  (41, 308),
#  (42, 7),
#  (43, 15186),
#  (44, 4451),
#  (45, 33505),
#  (46, 3417),
#  (47, 2017),
#  (48, 35),
#  (49, 45406),
#  (50, 99086),
#  (51, 205),
#  (52, 15397),
#  (53, 190083),
#  (54, 7250),
#  (55, 16116),
#  (56, 5734),
#  (57, 21),
#  (58, 89),
#  (59, 8209),
#  (60, 10237),
#  (61, 52),
#  (62, 26917),
#  (63, 115795),
#  (64, 493),
#  (65, 8231),
# ...

# %%
likeList = []
for key,value in list(youtubeDataSet["likes"].iteritems()):
    likeList.append(value)
print(likeList)
# Out:
# [57527, 97185, 146033, 10172, 132235, 9763, 15993, 23663, 3543, 12654, 655, 1576, 114188, 7848, 7473, 9419, 8011, 5398, 11963, 8421, 9586, 3585, 11758, 1707, 4884, 8676, 4687, 9033, 156, 715, 4035, 119, 787419, 3781, 1661, 2486, 7515, 1318, 38397, 6927, 5389, 308, 7, 15186, 4451, 33505, 3417, 2017, 35, 45406, 99086, 205, 15397, 190083, 7250, 16116, 5734, 21, 89, 8209, 10237, 52, 26917, 115795, 493, 8231, 115426, 120876, 203, 55681, 1634124, 2233, 2978, 1550, 18603, 2429, 1896, 37669, 15504, 355, 23296, 8133, 2323, 67, 3571, 6271, 16430, 439, 34839, 82320, 438, 72593, 2282, 98804, 58967, 8599, 40195, 16396, 202676, 14338, 43875, 22326, 1731, 3283, 286268, 307435, 3305, 10138, 3327, 5048, 53572, 7999, 88417, 52829, 25115, 14303, 7693, 25122, 4417, 5505, 15247, 11616, 9312, 9091, 84426, 935, 11198, 2926, 19323, 1365, 32648, 7683, 3652, 4364, 11736, 1345, 1354, 2163, 443, 909, 4604, 35765, 7158, 1991, 5642, 9210, 15909, 242, 65854, 810895, 16106, 11985, 20159, 10175, 31892, 49, 4989, 380
# ...

# %%
def likesAnddislikes(likes,dislikes):
    likesList = list()
    dislikesList = list()
    for key,value in likes.iteritems():
        likesList.append(value)
    for key,value in dislikes.iteritems():
        dislikesList.append(value)
    
    likeanddislikeratio = list()
    for like,dislike in zip(likesList,dislikesList): 
        if like + dislike == 0:
            likeanddislikeratio.append(0)
        else:
            likeanddislikeratio.append(like/(like + dislike))
    print(likeanddislikeratio)
    return likeanddislikeratio
        
likesAnddislikes(youtubeDataSet["likes"],youtubeDataSet["dislikes"])
# Out:
# [0.9509695336650521, 0.9405212375763323, 0.9647292762201728, 0.938549547887064, 0.9851814876624151, 0.9502627992992019, 0.8673934266189391, 0.9681682418886297, 0.9675040961223376, 0.9027609331526004, 0.9632352941176471, 0.8387440127727515, 0.988460972463881, 0.8701629892449274, 0.9681305868635833, 0.9945095554851653, 0.9262342467337265, 0.9902770133920381, 0.996999749979165, 0.977821644217371, 0.992236828485664, 0.9629331184528606, 0.9924875495906137, 0.7470459518599563, 0.9894651539708266, 0.978238809335889, 0.9913282571912013, 0.9758020957113536, 0.8125, 0.7502623294858342, 0.890728476821192, 0.6329787234042553, 0.9477395740931757, 0.9782664941785252, 0.9595609474292317, 0.9310861423220974, 0.90465872156013, 0.9821162444113264, 0.9651367383872914, 0.977285553047404, 0.9807097361237489, 0.9221556886227545, 0.5833333333333334, 0.49572370568649216, 0.7152498794793508, 0.9527939712782596, 0.9904347826086957, 0.4540747411076092, 0.660377358490566, 0.9410960039794396, 0.9866666666666667,
# ...

# %%
def likesAnddislikes(likes,dislikes):
    likesList = list()
    dislikesList = list()
    for key,value in likes.iteritems():
        likesList.append(value)
    for key,value in dislikes.iteritems():
        dislikesList.append(value)
    
    likeanddislikeratio = list()
    for like,dislike in zip(likesList,dislikesList): 
        if like + dislike == 0:
            likeanddislikeratio.append(0)
        else:
            likeanddislikeratio.append(like/(like + dislike))
    return likeanddislikeratio
        
youtubeDataSet["likes_dislikes"] = likesAnddislikes(youtubeDataSet["likes"],youtubeDataSet["dislikes"])

# %%
youtubeDataSet
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
youtubeDataSet.sort_values(by = "likes_dislikes",ascending = False,inplace=True)
youtubeDataSet
# Out:
#                                                    title        channel_title  \
# 8694                                  Christmas Day 2000             vnbreyes
# 16100                                  Magic Highway USA         Joshua Levin
# 921             #StarOnFox Exclusive Clip for TheYBF.com             YBF Chic
# 16369  First Responders Arrive To The Collapsed Floor...         9-1-1 on FOX
# 147    Improvising in the style of different classica...            Nahre Sol
# ...                                                  ...                  ...
# 15575       Official XFL Announcement with Vince McMahon  Alpha Entertainment
# 4752                      The New Snapchat in 60 Seconds             Snapchat
# 16590                                    To Our Daughter         Kylie Jenner
# 15510   Carolyn's RV Life Spots A Fluffy Kitty In Blythe      Caravan Carolyn
# 22020         GET READY WITH ME | Halo Beauty Launch Day                 Tati
#
# ...
